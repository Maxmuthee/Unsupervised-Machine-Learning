# %% [markdown]
# <a href="https://colab.research.google.com/github/Maxmuthee/Unsupervised-Machine-Learning/blob/main/Market_Basket_Example.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-5f4178c3-6edf-43ba-890e-f2f936b5cd48" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-5f4178c3-6edf-43ba-890e-f2f936b5cd48">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
# Load Dataset
import pandas as pd
data = pd.read_csv("Market_Basket_Optimisation.csv")

# printing the shape of the dataset
data
# Out:
#               shrimp            almonds      avocado    vegetables mix  \
# 0            burgers          meatballs         eggs               NaN
# 1            chutney                NaN          NaN               NaN
# 2             turkey            avocado          NaN               NaN
# 3      mineral water               milk   energy bar  whole wheat rice
# 4     low fat yogurt                NaN          NaN               NaN
# ...              ...                ...          ...               ...
# 7495          butter         light mayo  fresh bread               NaN
# 7496         burgers  frozen vegetables         eggs      french fries
# 7497         chicken                NaN          NaN               NaN
# 7498        escalope          green tea          NaN               NaN
# 7499            eggs    frozen smoothie  yogurt cake    low fat yogurt
#
#      green grapes whole weat flour yams cottage cheese energy drink  \
# ...

# %%
# Gather All Items of Each Transactions into Numpy Array
import numpy as np
transactions = []

for i in range(data.shape[0]):
    transaction = []
    for j in range(data.shape[1]):
        item = str(data.values[i, j])
        if item != 'nan':
            transaction.append(item)
    transactions.append(transaction)

# %%
# Flatten list of lists into one list of items
transactions_flat = [item for sublist in transactions for item in sublist]

# Create DataFrame
df = pd.DataFrame(transactions_flat, columns=["items"])

# Add incident count
df["incident_count"] = 1

# Drop NaN values
df = df[df["items"] != "nan"]

# Frequency table
df_table = df.groupby("items").sum().sort_values("incident_count", ascending=False).reset_index()

# Visualization
df_table.head(10).style.background_gradient(cmap='Greens')
# Out:
# <style type="text/css">
# #T_0e6f6_row0_col1 {
#   background-color: #00441b;
#   color: #f1f1f1;
# }
# #T_0e6f6_row1_col1 {
#   background-color: #4eb264;
#   color: #f1f1f1;
# }
# #T_0e6f6_row2_col1 {
#   background-color: #5eb96b;
#   color: #f1f1f1;
# }
# #T_0e6f6_row3_col1 {
#   background-color: #68be70;
#   color: #000000;
# }
# #T_0e6f6_row4_col1 {
#   background-color: #7ac77b;
#   color: #000000;
# }
# #T_0e6f6_row5_col1 {
#   background-color: #c4e8bd;
#   color: #000000;
# }
# #T_0e6f6_row6_col1 {
#   background-color: #caeac3;
#   color: #000000;
# }
# #T_0e6f6_row7_col1 {
#   background-color: #f4fbf2;
#   color: #000000;
# }
# #T_0e6f6_row8_col1, #T_0e6f6_row9_col1 {
#   background-color: #f7fcf5;
#   color: #000000;
# }
# </style>
# <table id="T_0e6f6" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_0e6f6_level0_col0" class="col_heading level0 col0" >items</th>
# ...

# %%
# importing the required module
from mlxtend.preprocessing import TransactionEncoder
# initializing the transactionEncoder
te = TransactionEncoder()
te_ary = te.fit(transactions).transform(transactions)
dataset = pd.DataFrame(te_ary, columns=te.columns_)
# dataset after encoded
dataset
# Out:
#        asparagus  almonds  antioxydant juice  asparagus  avocado  babies food  \
# 0          False    False              False      False    False        False
# 1          False    False              False      False    False        False
# 2          False    False              False      False     True        False
# 3          False    False              False      False    False        False
# 4          False    False              False      False    False        False
# ...          ...      ...                ...        ...      ...          ...
# 7495       False    False              False      False    False        False
# 7496       False    False              False      False    False        False
# 7497       False    False              False      False    False        False
# 7498       False    False              False      False    False        False
# 7499       False    False              False      False    False        False
#
# ...

# %%
# 121 items are too many and some occur a few times only
# so we select the most common

# select top 50 items
first50 = df_table["items"].head(50).values

# Create dataset with Top50
dataset = dataset.reindex(columns = first50)
dataset
# Out:
#       mineral water   eggs  spaghetti  french fries  chocolate  green tea  \
# 0             False   True      False         False      False      False
# 1             False  False      False         False      False      False
# 2             False  False      False         False      False      False
# 3              True  False      False         False      False       True
# 4             False  False      False         False      False      False
# ...             ...    ...        ...           ...        ...        ...
# 7495          False  False      False         False      False      False
# 7496          False   True      False          True      False       True
# 7497          False  False      False         False      False      False
# 7498          False  False      False         False      False       True
# 7499          False   True      False         False      False      False
#
#        milk  ground beef  frozen vegetables  pancakes  ...  energy bar    ham  \
# ...

# %%
import warnings
warnings.filterwarnings("ignore", category=DeprecationWarning)
# importing the required module
from mlxtend.frequent_patterns import apriori, association_rules


# Extracting the the rules (most frequest items)
frequent_itemsets = apriori(dataset, min_support=0.01, use_colnames=True)

# We add the length column simplify filtering filtering.
frequent_itemsets['length'] = frequent_itemsets['itemsets'].apply(lambda x: len(x))
# printing the frequent itemset
frequent_itemsets
# Out:
# /usr/local/lib/python3.12/dist-packages/jupyter_client/session.py:203: DeprecationWarning: datetime.datetime.utcnow() is deprecated and scheduled for removal in a future version. Use timezone-aware objects to represent datetimes in UTC: datetime.datetime.now(datetime.UTC).
#   return datetime.utcnow().replace(tzinfo=utc)
#       support                                  itemsets  length
# 0    0.238267                           (mineral water)       1
# 1    0.179733                                    (eggs)       1
# 2    0.174133                               (spaghetti)       1
# 3    0.170933                            (french fries)       1
# 4    0.163867                               (chocolate)       1
# ..        ...                                       ...     ...
# 229  0.010933   (mineral water, chocolate, ground beef)       3
# 230  0.011067        (mineral water, ground beef, milk)       3
# 231  0.011067  (mineral water, milk, frozen vegetables)       3
# ...

# %%
# printing with more than two items and support above 0.05
frequent_itemsets[ (frequent_itemsets['length'] == 2) &
                   (frequent_itemsets['support'] >= 0.05) ]
# Out:
# /usr/local/lib/python3.12/dist-packages/jupyter_client/session.py:203: DeprecationWarning: datetime.datetime.utcnow() is deprecated and scheduled for removal in a future version. Use timezone-aware objects to represent datetimes in UTC: datetime.datetime.now(datetime.UTC).
#   return datetime.utcnow().replace(tzinfo=utc)
# /usr/local/lib/python3.12/dist-packages/jupyter_client/session.py:203: DeprecationWarning: datetime.datetime.utcnow() is deprecated and scheduled for removal in a future version. Use timezone-aware objects to represent datetimes in UTC: datetime.datetime.now(datetime.UTC).
#   return datetime.utcnow().replace(tzinfo=utc)
# /usr/local/lib/python3.12/dist-packages/jupyter_client/session.py:203: DeprecationWarning: datetime.datetime.utcnow() is deprecated and scheduled for removal in a future version. Use timezone-aware objects to represent datetimes in UTC: datetime.datetime.now(datetime.UTC).
#   return datetime.utcnow().replace(tzinfo=utc)
# ...

# %%
# Searching for specific rule
# in sets the order does not matter
frequent_itemsets[ (frequent_itemsets['itemsets'] == {'eggs', 'mineral water'}) ]
# Out:
# /usr/local/lib/python3.12/dist-packages/jupyter_client/session.py:203: DeprecationWarning: datetime.datetime.utcnow() is deprecated and scheduled for removal in a future version. Use timezone-aware objects to represent datetimes in UTC: datetime.datetime.now(datetime.UTC).
#   return datetime.utcnow().replace(tzinfo=utc)
# /usr/local/lib/python3.12/dist-packages/jupyter_client/session.py:203: DeprecationWarning: datetime.datetime.utcnow() is deprecated and scheduled for removal in a future version. Use timezone-aware objects to represent datetimes in UTC: datetime.datetime.now(datetime.UTC).
#   return datetime.utcnow().replace(tzinfo=utc)
# /usr/local/lib/python3.12/dist-packages/jupyter_client/session.py:203: DeprecationWarning: datetime.datetime.utcnow() is deprecated and scheduled for removal in a future version. Use timezone-aware objects to represent datetimes in UTC: datetime.datetime.now(datetime.UTC).
#   return datetime.utcnow().replace(tzinfo=utc)
# ...

# %%
# Searching for specific rule
# in sets the order does not matter
frequent_itemsets[ (frequent_itemsets['itemsets'] == {'eggs', 'mineral water'}) ]
# Out:
# /usr/local/lib/python3.12/dist-packages/jupyter_client/session.py:203: DeprecationWarning: datetime.datetime.utcnow() is deprecated and scheduled for removal in a future version. Use timezone-aware objects to represent datetimes in UTC: datetime.datetime.now(datetime.UTC).
#   return datetime.utcnow().replace(tzinfo=utc)
# /usr/local/lib/python3.12/dist-packages/jupyter_client/session.py:203: DeprecationWarning: datetime.datetime.utcnow() is deprecated and scheduled for removal in a future version. Use timezone-aware objects to represent datetimes in UTC: datetime.datetime.now(datetime.UTC).
#   return datetime.utcnow().replace(tzinfo=utc)
# /usr/local/lib/python3.12/dist-packages/jupyter_client/session.py:203: DeprecationWarning: datetime.datetime.utcnow() is deprecated and scheduled for removal in a future version. Use timezone-aware objects to represent datetimes in UTC: datetime.datetime.now(datetime.UTC).
#   return datetime.utcnow().replace(tzinfo=utc)
# ...

# %%
#print rules with eggs in them
mylist=list(frequent_itemsets['itemsets'])

sub = 'eggs'
print( [s for s in mylist if sub in s])
# Out:
# [frozenset({'eggs'}), frozenset({'mineral water', 'eggs'}), frozenset({'spaghetti', 'eggs'}), frozenset({'french fries', 'eggs'}), frozenset({'eggs', 'chocolate'}), frozenset({'green tea', 'eggs'}), frozenset({'milk', 'eggs'}), frozenset({'eggs', 'ground beef'}), frozenset({'frozen vegetables', 'eggs'}), frozenset({'pancakes', 'eggs'}), frozenset({'eggs', 'burgers'}), frozenset({'cake', 'eggs'}), frozenset({'cookies', 'eggs'}), frozenset({'eggs', 'escalope'}), frozenset({'eggs', 'low fat yogurt'}), frozenset({'shrimp', 'eggs'}), frozenset({'tomatoes', 'eggs'}), frozenset({'eggs', 'olive oil'}), frozenset({'eggs', 'frozen smoothie'}), frozenset({'eggs', 'turkey'}), frozenset({'chicken', 'eggs'}), frozenset({'whole wheat rice', 'eggs'}), frozenset({'eggs', 'cooking oil'}), frozenset({'eggs', 'herb & pepper'}), frozenset({'spaghetti', 'mineral water', 'eggs'}), frozenset({'mineral water', 'eggs', 'chocolate'}), frozenset({'mineral water', 'eggs', 'milk'}), frozenset({'mineral water', 'e
# ...

# %%
rules = association_rules(frequent_itemsets, metric="lift", min_threshold=1)

#convert rules to lists
rules = rules.sort_values(['lift'], ascending =[False])

#From Frozenset to string
rules["antecedents"] = rules["antecedents"].apply(lambda x: list(x)[0]).astype("unicode")
rules["consequents"] = rules["consequents"].apply(lambda x: list(x)[0]).astype("unicode")
#Table with most relevant rules
rules.sort_values('lift', ascending=False).nlargest(10, 'lift')
# Out:
#            antecedents        consequents  antecedent support  \
# 277        ground beef      herb & pepper            0.098267
# 276      herb & pepper        ground beef            0.049467
# 348          spaghetti        ground beef            0.059733
# 353        ground beef          spaghetti            0.098267
# 366          spaghetti          olive oil            0.059733
# 371          olive oil          spaghetti            0.065733
# 288  frozen vegetables           tomatoes            0.095333
# 289           tomatoes  frozen vegetables            0.068400
# 286             shrimp  frozen vegetables            0.071333
# 287  frozen vegetables             shrimp            0.095333
#
#      consequent support   support  confidence      lift  representativity  \
# 277            0.049467  0.016000    0.162822  3.291555               1.0
# 276            0.098267  0.016000    0.323450  3.291555               1.0
# ...
